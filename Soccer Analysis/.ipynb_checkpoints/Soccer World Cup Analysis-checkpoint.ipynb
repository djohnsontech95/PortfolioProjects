# %%
# Soccer World Cup Analysis

# %%
## Import Libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,12)

pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)

### Read in necessary files  

df_teams = pd.read_csv(r'C:\Users\Dylan\Documents\Personal\Projects\PythonProjects\Soccer_Analysis\teams.csv')
df_team_appearances = pd.read_csv(r'C:\Users\Dylan\Documents\Personal\Projects\PythonProjects\Soccer_Analysis\team_appearances.csv')
df_goals = pd.read_csv(r'C:\Users\Dylan\Documents\Personal\Projects\PythonProjects\Soccer_Analysis\goals.csv')
df_tournaments = pd.read_csv(r'C:\Users\Dylan\Documents\Personal\Projects\PythonProjects\Soccer_Analysis\tournaments.csv')

# %%
### Initial look at data
df_team_appearances.head()
# Out:
#    key_id tournament_id            tournament_name   match_id  \
# 0       1       WC-1930  1930 FIFA Men's World Cup  M-1930-01
# 1       2       WC-1930  1930 FIFA Men's World Cup  M-1930-01
# 2       3       WC-1930  1930 FIFA Men's World Cup  M-1930-02
# 3       4       WC-1930  1930 FIFA Men's World Cup  M-1930-02
# 4       5       WC-1930  1930 FIFA Men's World Cup  M-1930-03
#
#                  match_name   stage_name group_name  group_stage  \
# 0          France vs Mexico  group stage    Group 1            1
# 1          France vs Mexico  group stage    Group 1            1
# 2  United States vs Belgium  group stage    Group 4            1
# 3  United States vs Belgium  group stage    Group 4            1
# 4      Yugoslavia vs Brazil  group stage    Group 2            1
#
#    knockout_stage  replayed  ...  goals_against goal_differential extra_time  \
# 0               0         0  ...              1                 3          0
# ...

# %%
### Checking data types
df_team_appearances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2496 entries, 0 to 2495
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key_id             2496 non-null   int64
#  1   tournament_id      2496 non-null   object
#  2   tournament_name    2496 non-null   object
#  3   match_id           2496 non-null   object
#  4   match_name         2496 non-null   object
#  5   stage_name         2496 non-null   object
#  6   group_name         2496 non-null   object
#  7   group_stage        2496 non-null   int64
#  8   knockout_stage     2496 non-null   int64
#  9   replayed           2496 non-null   int64
#  10  replay             2496 non-null   int64
#  11  match_date         2496 non-null   object
#  12  match_time         2496 non-null   object
#  13  stadium_id         2496 non-null   object
#  14  stadium_name       2496 non-null   object
#  15  city_name          2496 non-null   object
# ...

# %%
### Checking for empty or missing values
df_team_appearances.isnull().sum()
# Out:
# key_id               0
# tournament_id        0
# tournament_name      0
# match_id             0
# match_name           0
#                     ..
# penalties_against    0
# result               0
# win                  0
# lose                 0
# draw                 0
# Length: 36, dtype: int64

# %%
### Counts the number of wins per team, combined mens and womens teams 
wins_per_team = df_team_appearances[df_team_appearances['result'] == 'win']['team_name'].value_counts()

### Top 10 number of wins per team
top_10_wins = wins_per_team.nlargest(10)

### Display the results
print(top_10_wins)
# Out:
# Brazil           100
# Germany           64
# Argentina         53
# France            52
# Italy             52
# United States     51
# England           48
# Sweden            43
# West Germany      39
# Netherlands       38
# Name: team_name, dtype: int64

# %%
## Horizontal bar graph visual of number of wins per team
wins_per_team.plot(kind='barh', color='skyblue')
plt.title("Number of Wins per Team")
plt.xlabel('Number of Wins')
plt.ylabel('Teams')
plt.tight_layout()
plt.show()

# %%
## Top 10 number of games won per team visual for better analysis
top_10_wins.plot(kind='bar', color='skyblue')
plt.title("Top 10 Teams with the Most Wins")
plt.xlabel('Teams')
plt.ylabel('Number of Wins')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
### Initial look at new data set
df_tournaments.head()
# Out:
#    key_id tournament_id            tournament_name  year  start_date  \
# 0       1       WC-1930  1930 FIFA Men's World Cup  1930  1930-07-13
# 1       2       WC-1934  1934 FIFA Men's World Cup  1934  1934-05-27
# 2       3       WC-1938  1938 FIFA Men's World Cup  1938  1938-06-04
# 3       4       WC-1950  1950 FIFA Men's World Cup  1950  1950-06-24
# 4       5       WC-1954  1954 FIFA Men's World Cup  1954  1954-06-16
#
#      end_date host_country        winner  host_won  count_teams  group_stage  \
# 0  1930-07-30      Uruguay       Uruguay         1           13            1
# 1  1934-06-10        Italy         Italy         1           16            0
# 2  1938-06-19       France         Italy         0           15            0
# 3  1950-07-16       Brazil       Uruguay         0           13            1
# 4  1954-07-04  Switzerland  West Germany         0           16            1
#
#    second_group_stage  final_round  round_of_16  quarter_finals  semi_finals  \
# ...

# %%
### Looking at data types
df_tournaments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   key_id              30 non-null     int64
#  1   tournament_id       30 non-null     object
#  2   tournament_name     30 non-null     object
#  3   year                30 non-null     int64
#  4   start_date          30 non-null     object
#  5   end_date            30 non-null     object
#  6   host_country        30 non-null     object
#  7   winner              30 non-null     object
#  8   host_won            30 non-null     int64
#  9   count_teams         30 non-null     int64
#  10  group_stage         30 non-null     int64
#  11  second_group_stage  30 non-null     int64
#  12  final_round         30 non-null     int64
#  13  round_of_16         30 non-null     int64
#  14  quarter_finals      30 non-null     int64
#  15  semi_finals         30 non-null     int64
# ...

# %%
### Checking for empty values
df_tournaments.isnull().sum()
# Out:
# key_id                0
# tournament_id         0
# tournament_name       0
# year                  0
# start_date            0
# end_date              0
# host_country          0
# winner                0
# host_won              0
# count_teams           0
# group_stage           0
# second_group_stage    0
# final_round           0
# round_of_16           0
# quarter_finals        0
# semi_finals           0
# third_place_match     0
# final                 0
# dtype: int64

# %%
### Count all unique values in the winner column
winner_counts = df_tournaments['winner'].value_counts()

print(winner_counts)
# Out:
# Brazil           5
# Italy            4
# United States    4
# West Germany     3
# Argentina        3
# Germany          3
# Uruguay          2
# France           2
# England          1
# Norway           1
# Spain            1
# Japan            1
# Name: winner, dtype: int64

# %%
## Create a bar chart
plt.bar(winner_counts.index, winner_counts.values, color='skyblue')

### Add labels and title
plt.xlabel('Teams')
plt.ylabel('Number of World Cups Won')
plt.title('Distribution of World Cup Winners')

### Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

### Show the plot
plt.show()

# %%
### Initial look at goals data 
df_goals.head()
# Out:
#    key_id goal_id tournament_id            tournament_name   match_id  \
# 0       1  G-0001       WC-1930  1930 FIFA Men's World Cup  M-1930-01
# 1       2  G-0002       WC-1930  1930 FIFA Men's World Cup  M-1930-01
# 2       3  G-0003       WC-1930  1930 FIFA Men's World Cup  M-1930-01
# 3       4  G-0004       WC-1930  1930 FIFA Men's World Cup  M-1930-01
# 4       5  G-0005       WC-1930  1930 FIFA Men's World Cup  M-1930-01
#
#          match_name  match_date   stage_name group_name team_id team_name  \
# 0  France vs Mexico  1930-07-13  group stage    Group 1    T-30    France
# 1  France vs Mexico  1930-07-13  group stage    Group 1    T-30    France
# 2  France vs Mexico  1930-07-13  group stage    Group 1    T-30    France
# 3  France vs Mexico  1930-07-13  group stage    Group 1    T-46    Mexico
# 4  France vs Mexico  1930-07-13  group stage    Group 1    T-30    France
#
#   team_code  home_team  away_team player_id family_name given_name  \
# ...

# %%
### Checking data types
df_goals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3637 entries, 0 to 3636
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key_id             3637 non-null   int64
#  1   goal_id            3637 non-null   object
#  2   tournament_id      3637 non-null   object
#  3   tournament_name    3637 non-null   object
#  4   match_id           3637 non-null   object
#  5   match_name         3637 non-null   object
#  6   match_date         3637 non-null   object
#  7   stage_name         3637 non-null   object
#  8   group_name         3637 non-null   object
#  9   team_id            3637 non-null   object
#  10  team_name          3637 non-null   object
#  11  team_code          3637 non-null   object
#  12  home_team          3637 non-null   int64
#  13  away_team          3637 non-null   int64
#  14  player_id          3637 non-null   object
#  15  family_name        3637 non-null   object
# ...

# %%
### Quick look at statistics on goals data
df_goals.describe()
# Out:
#             key_id    home_team    away_team  shirt_number  minute_regulation  \
# count  3637.000000  3637.000000  3637.000000   3637.000000        3637.000000
# mean   1819.000000     0.619742     0.380258     10.528732          51.168546
# std    1050.055792     0.485517     0.485517      5.743036          27.388687
# min       1.000000     0.000000     0.000000      0.000000           1.000000
# 25%     910.000000     0.000000     0.000000      7.000000          27.000000
# 50%    1819.000000     1.000000     0.000000     10.000000          52.000000
# 75%    2728.000000     1.000000     1.000000     15.000000          75.000000
# max    3637.000000     1.000000     1.000000     26.000000         120.000000
#
#        minute_stoppage     own_goal      penalty
# count      3637.000000  3637.000000  3637.000000
# mean          0.119879     0.021721     0.080286
# std           0.697263     0.145792     0.271773
# min           0.000000     0.000000     0.000000
# ...

# %%
### Checking for empty or null values
df_goals.isnull().sum()
# Out:
# key_id             0
# goal_id            0
# tournament_id      0
# tournament_name    0
# match_id           0
#                   ..
# minute_stoppage    0
# match_period       0
# own_goal           0
# penalty            0
# match_year         0
# Length: 28, dtype: int64

# %%
### Counts the number of goals per team
goals_per_team = df_goals['team_name'].value_counts()

### Top 10 goals scored per team
top_10_goals = goals_per_team.nlargest(10)

### Bottom 10 on gaols scored
lowest_10_goals = goals_per_team.nsmallest(10)

### Print results
print("Top 10 teams with the most goals scored:")
print(top_10_goals)
print("\nBottom 10 teams with the least amount of goals scored:")
print(lowest_10_goals)
# Out:
# Top 10 teams with the most goals scored:
# Brazil           303
# Germany          222
# United States    178
# France           168
# Argentina        157
# Sweden           151
# Italy            148
# England          147
# West Germany     131
# Spain            114
# Name: team_name, dtype: int64
#
# Bottom 10 teams with the least amount of goals scored:
# El Salvador              1
# Angola                   1
# Togo                     1
# Bolivia                  1
# Iraq                     1
# Israel                   1
# Qatar                    1
# Serbia and Montenegro    2
# Equatorial Guinea        2
# Panama                   2
# Name: team_name, dtype: int64

# %%
## Number of goals per team horizontal bar graph visualization
goals_per_team.plot(kind='barh', color='skyblue')
plt.title("Number of Goals per Team")
plt.xlabel('Goals Scored')
plt.ylabel('Teams')
plt.tight_layout()
plt.show()

# %%
## Top 10 goals per team bar graph visual for better analysis
top_10_goals.plot(kind='bar', color='skyblue')
plt.title("Top 10 Teams With the Most Goals")
plt.xlabel('Teams')
plt.ylabel('Goals Scored')
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
### Create a new column with the year of each match
df_goals['match_year'] = df_goals['match_date'].astype(str).str[:4]

# %%
### Group by match_year and team_name to organize by year and count the number of team occurances
### Creates a new column called yearly_goals to hold all the new data
yearly_goals_per_team = df_goals.groupby(['match_year', 'team_name']).size().reset_index(name='goals_in_year')

print(yearly_goals_per_team)
# Out:
#     match_year      team_name  goals_in_year
# 0         1930      Argentina             18
# 1         1930         Brazil              5
# 2         1930          Chile              5
# 3         1930         France              4
# 4         1930         Mexico              4
# ..         ...            ...            ...
# 595       2022    Switzerland              5
# 596       2022        Tunisia              1
# 597       2022  United States              3
# 598       2022        Uruguay              2
# 599       2022          Wales              1
#
# [600 rows x 3 columns]

# %%
### Pivot the data to create a matrix with countries as rows, years as columns, and total goals as values
yearly_goals_heatmap = yearly_goals_per_team.pivot('team_name', 'match_year', 'goals_in_year')

## Create the heatmap
plt.figure(figsize=(15, 14))
sns.heatmap(yearly_goals_heatmap, cmap='YlGnBu', annot=True, fmt='g', linewidths=.5)
plt.title('Total Goals Scored by Each Team Over the Years')
plt.xticks(rotation=45)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Teams', fontsize=14)
plt.show()
# Out:
# C:\Users\Dylan\AppData\Local\Temp\ipykernel_27024\2210743123.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   yearly_goals_heatmap = yearly_goals_per_team.pivot('team_name', 'match_year', 'goals_in_year')

# %%
### Setup data
team_data = yearly_goals_per_team.pivot('match_year', 'team_name', 'goals_in_year')

### Calculate the yearly percentage change for each team
percentage_change = team_data.pct_change() * 100

### Identify teams with the most significant positive changes
most_improved_teams = percentage_change.max().nlargest(5)

### Identify teams with the most significant negative changes
most_declined_teams = percentage_change.min().nsmallest(5)

print("Most Improved Teams:")
print(most_improved_teams)
print("\nMost Declined Teams:")
print(most_declined_teams)
# Out:
# Most Improved Teams:
# team_name
# Norway           2200.0
# United States    1700.0
# Brazil           1300.0
# Colombia         1100.0
# Argentina        1000.0
# dtype: float64
#
# Most Declined Teams:
# team_name
# Belgium         -93.750000
# United States   -93.333333
# Norway          -92.857143
# France          -91.304348
# Argentina       -90.909091
# dtype: float64
# C:\Users\Dylan\AppData\Local\Temp\ipykernel_27024\4290244856.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   team_data = yearly_goals_per_team.pivot('match_year', 'team_name', 'goals_in_year')

# %%
### Calculate the total goals scored per year
total_goals_per_year = yearly_goals_per_team.groupby('match_year')['goals_in_year'].sum()

### Merge the total goals information back into the yearly_goals_per_team DataFrame
yearly_goals_per_team = pd.merge(yearly_goals_per_team, total_goals_per_year.rename('total_goals'), on='match_year', how='left')

### Calculate the probability that a team scores in a given year
yearly_goals_per_team['probability'] = (yearly_goals_per_team['goals_in_year'] / yearly_goals_per_team['total_goals']) * 100

print(yearly_goals_per_team)
# Out:
#     match_year      team_name  goals_in_year  total_goals  probability
# 0         1930      Argentina             18           70    25.714286
# 1         1930         Brazil              5           70     7.142857
# 2         1930          Chile              5           70     7.142857
# 3         1930         France              4           70     5.714286
# 4         1930         Mexico              4           70     5.714286
# ..         ...            ...            ...          ...          ...
# 595       2022    Switzerland              5          172     2.906977
# 596       2022        Tunisia              1          172     0.581395
# 597       2022  United States              3          172     1.744186
# 598       2022        Uruguay              2          172     1.162791
# 599       2022          Wales              1          172     0.581395
#
# [600 rows x 5 columns]

# %%
### Find the top 5 highest probabilities across all rows
top_5_probabilities = yearly_goals_per_team['probability'].nlargest(5)

### Find the corresponding team and year for the top 5 probabilities
top_5_teams_years = yearly_goals_per_team.loc[yearly_goals_per_team['probability'].isin(top_5_probabilities)].reset_index(drop=True)

### Display the result
print(top_5_teams_years)
# Out:
#   match_year      team_name  goals_in_year  total_goals  probability
# 0       1930      Argentina             18           70    25.714286
# 1       1950         Brazil             22           88    25.000000
# 2       1991  United States             25           99    25.252525
# 3       1995         Norway             23           99    23.232323
# 4       2003        Germany             25          107    23.364486

# %%
### Count the occurrences of each unique tournament_id
tournament_match_counts = df_team_appearances['tournament_id'].value_counts()

### Divide by 2 to get the actual number of matches
actual_number_of_matches = tournament_match_counts / 2

### Sorts the index in DESC order
actual_number_of_matches = actual_number_of_matches.sort_index()

# %%
### Reset the index of actual_number_of_matches to create a DataFrame
number_of_matches_df = actual_number_of_matches.reset_index()
### Create column names for entries
number_of_matches_df.columns = ['tournament_id', 'total_matches']
### Create new column for match_year
number_of_matches_df['match_year'] = number_of_matches_df['tournament_id'].str[-4:]

### Merge DataFrames on the common column 'match_year'
merged_df = pd.merge(yearly_goals_per_team, number_of_matches_df, on='match_year')

### Add a new column 'total_matches' to yearly_goals_per_team
yearly_goals_per_team['total_matches'] = merged_df['total_matches']

print(yearly_goals_per_team)
# Out:
#     match_year      team_name  goals_in_year  total_goals  probability  \
# 0         1930      Argentina             18           70    25.714286
# 1         1930         Brazil              5           70     7.142857
# 2         1930          Chile              5           70     7.142857
# 3         1930         France              4           70     5.714286
# 4         1930         Mexico              4           70     5.714286
# ..         ...            ...            ...          ...          ...
# 595       2022    Switzerland              5          172     2.906977
# 596       2022        Tunisia              1          172     0.581395
# 597       2022  United States              3          172     1.744186
# 598       2022        Uruguay              2          172     1.162791
# 599       2022          Wales              1          172     0.581395
#
#     tournament_id  total_matches
# 0         WC-1930           18.0
# 1         WC-1930           18.0
# ...

# %%
### Calculate the average goals per match for each unique 'match_year'
yearly_goals_per_team['average_goals_per_match'] = yearly_goals_per_team['total_goals'] / yearly_goals_per_team['total_matches']

### Round the 'average_goals_per_match' column to two decimal places
yearly_goals_per_team['average_goals_per_match'] = yearly_goals_per_team['average_goals_per_match'].round(2)

print(yearly_goals_per_team)
# Out:
#     match_year      team_name  goals_in_year  total_goals  probability  \
# 0         1930      Argentina             18           70    25.714286
# 1         1930         Brazil              5           70     7.142857
# 2         1930          Chile              5           70     7.142857
# 3         1930         France              4           70     5.714286
# 4         1930         Mexico              4           70     5.714286
# ..         ...            ...            ...          ...          ...
# 595       2022    Switzerland              5          172     2.906977
# 596       2022        Tunisia              1          172     0.581395
# 597       2022  United States              3          172     1.744186
# 598       2022        Uruguay              2          172     1.162791
# 599       2022          Wales              1          172     0.581395
#
#      total_matches  average_goals_per_match
# 0             18.0                     3.89
# ...

# %%
### Top 5 years with the highest amount of goals scored on average
top_5_years = yearly_goals_per_team.groupby('match_year')['average_goals_per_match'].max().nlargest(5)

print("Top 5 years with the highest amount of goals scored on average:")
print(top_5_years)
# Out:
# Top 5 years with the highest amount of goals scored on average:
# match_year
# 1954    5.38
# 1938    4.67
# 1934    4.12
# 1950    4.00
# 1930    3.89
# Name: average_goals_per_match, dtype: float64

# %%
### Count the number of unique tournament IDs 
world_cups_count = df_team_appearances['tournament_id'].nunique()

### Drop duplicate rows based on 'match_year' (only to figure out average across all World Cups)
unique_goals_per_year = yearly_goals_per_team.drop_duplicates(subset='match_year')

### Calculate the overall average goals across all World Cups
overall_average_goals = unique_goals_per_year['average_goals_per_match'].mean().round(2)

### Display overall average goals result
print("Overall average goals scored in any given World Cup:")
print(overall_average_goals)
# Out:
# Overall average goals scored in any given World Cup:
# 3.13

# %%
### Create a line plot to visualize the change in average goals per World Cup over the years
sns.lineplot(x=yearly_goals_per_team['match_year'], y=yearly_goals_per_team['average_goals_per_match'], marker='o', color='skyblue')

### Set plot title and labels
plt.title('Change in Average Goals per World Cup Over the Years', fontsize=16)
plt.xlabel('Match Year', fontsize=14)
plt.ylabel('Average Goals per World Cup', fontsize=14)

### Rotate x-axis labels for better readability
plt.xticks(rotation=45)

## Change in average goals per world cup over the years
plt.show()

# %%
### Filter the data for the year 1954
year_1954_data = yearly_goals_per_team[yearly_goals_per_team['match_year'] == '1954']


### Grab team_name and goals_in_year from this data
result = year_1954_data[['team_name', 'goals_in_year']]

#### print(result['goals_in_year'].max())

## Create visual to analyze data
result.plot(x='team_name', y='goals_in_year', kind='bar', legend=False, color='skyblue')
plt.title('Team Goals in 1954 World Cup')
plt.xlabel('Teams')
plt.ylabel('Number of Goals')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
## Insights:

### Brazil has won the most soccer matches

### Brazil has the most goals scored in games

### Brazil has won the most World Cups

### Norway had the best improvement in goals scored

### Belgium had the worst decline in scoring goals

### Argentina had the highest probability of scoring a goal out of all teams in every World Cup
### in 1930 at a 25.71% chance

### The World Cup of 1954 had the highest average goals scored in a match at: 5.38 goals

### Hungary scored the most goals in 1954: 27 Goals

### On average in any World Cup match, about 3.13 goals were scored
